# %% [markdown]
# <a href="https://colab.research.google.com/github/prksh830/Healthcare/blob/main/eegraphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data (approximated from the figure)
nodes = np.array([0, 100, 200, 300, 400, 500])

mee_wsn_dt = [80, 86, 88.5, 91, 94.5, 95.5]
ee_mpdp_wsn = [70, 75.5, 78.5, 82.5, 85.5, 88.8]
lmnn_ee_wsn = [58, 63.5, 66.5, 70, 73.5, 76]
ee_iot_wsn_ggnn = [95, 97.5, 98.7, 99.4, 99.6, 99.8]

plt.figure(figsize=(8,5))

# Plot lines with thicker width
plt.plot(nodes, mee_wsn_dt, marker='D', linewidth=3, markersize=8,
         label='MEE-WSN-DT')

plt.plot(nodes, ee_mpdp_wsn, marker='^', linewidth=3, markersize=8,
         label='EE-MPDP-WSN')

plt.plot(nodes, lmnn_ee_wsn, marker='s', linewidth=3, markersize=8,
         label='LMNN-EE-WSN')

plt.plot(nodes, ee_iot_wsn_ggnn, marker='o', linewidth=3.5, markersize=8,
         label='EE-IoT-WSN-GGNN (Proposed)')

# Labels
plt.xlabel("Nodes", fontsize=13, fontweight='bold')
plt.ylabel("Energy Efficiency (%)", fontsize=13, fontweight='bold')

# Axis limits
plt.xlim(0,500)
plt.ylim(50,100)

# Legend with thicker handles
plt.legend(fontsize=11, frameon=True)

# Grid for readability
plt.grid(True, linestyle='--', alpha=0.6)

# Tight layout
plt.tight_layout()

# Save for journal
plt.savefig("energy_efficiency_plot.tiff", dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the figure
nodes = np.array([0, 100, 200, 300, 400, 500])

mee_wsn_dt = [80, 86, 88.5, 91, 94.5, 95.5]
ee_mpdp_wsn = [70, 75.5, 78.5, 82.5, 85.5, 88.8]
lmnn_ee_wsn = [58, 63.5, 66.5, 70, 73.5, 76]
ee_iot_wsn_ggnn = [95, 97.5, 98.7, 99.4, 99.6, 99.8]

plt.figure(figsize=(8,5))

plt.plot(nodes, mee_wsn_dt, marker='D', linewidth=3, markersize=8,
         label='MEE-WSN-DT')

plt.plot(nodes, ee_mpdp_wsn, marker='^', linewidth=3, markersize=8,
         label='EE-MPDP-WSN')

plt.plot(nodes, lmnn_ee_wsn, marker='s', linewidth=3, markersize=8,
         label='LMNN-EE-WSN')

plt.plot(nodes, ee_iot_wsn_ggnn, marker='o', linewidth=3.5, markersize=8,
         label='EE-IoT-WSN-GGNN (Proposed)')

plt.xlabel("Nodes", fontsize=13, fontweight='bold')
plt.ylabel("Energy Efficiency (%)", fontsize=13, fontweight='bold')

plt.xlim(0,500)
plt.ylim(50,100)

plt.legend(fontsize=11, frameon=True)
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()

# Save high-quality images
plt.savefig("energy_efficiency_plot.png", dpi=600, bbox_inches='tight')
plt.savefig("energy_efficiency_plot.jpeg", dpi=600, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

nodes = np.array([0,100,200,300,400,500])
time = np.array([0,200,400,600,800,1000])

# -------- Figure 1 : Network Stability --------
mee = [89.1, 89.7, 89.8, 90.1, 90.2, 90.4]
mpdp = [87.2, 87.4, 87.6, 87.9, 88.1, 88.3]
lmnn = [85.1, 85.3, 85.5, 85.8, 86.0, 86.3]
ggnn = [92.0, 92.2, 92.6, 92.9, 93.2, 93.5]

plt.figure(figsize=(7,4.5))

plt.plot(nodes, mee, marker='D', linewidth=3, markersize=8,label='MEE-WSN-DT')
plt.plot(nodes, mpdp, marker='v', linewidth=3, markersize=8,label='EE-MPDP-WSN')
plt.plot(nodes, lmnn, marker='s', linewidth=3, markersize=8,label='LMNN-EE-WSN')
plt.plot(nodes, ggnn, marker='o', linewidth=3.5, markersize=8,label='EE-IoT-WSN-GGNN(Proposed)')

plt.xlabel("Nodes",fontsize=12,fontweight='bold')
plt.ylabel("Network stability",fontsize=12,fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True,alpha=0.4)

plt.tight_layout()
plt.savefig("network_stability.png",dpi=600)
plt.savefig("network_stability.jpeg",dpi=600)
plt.savefig("network_stability.tiff",dpi=600)
plt.close()

# -------- Figure 2 : Network Scalability --------
mee = [0.54,0.61,0.66,0.70,0.74,0.79]
mpdp = [0.38,0.42,0.47,0.49,0.54,0.57]
lmnn = [0.19,0.21,0.24,0.27,0.29,0.31]
ggnn = [0.79,0.82,0.86,0.88,0.93,0.97]

plt.figure(figsize=(7,4.5))

plt.plot(nodes, mee, marker='D', linewidth=3, markersize=8,label='MEE-WSN-DT')
plt.plot(nodes, mpdp, marker='v', linewidth=3, markersize=8,label='EE-MPDP-WSN')
plt.plot(nodes, lmnn, marker='s', linewidth=3, markersize=8,label='LMNN-EE-WSN')
plt.plot(nodes, ggnn, marker='o', linewidth=3.5, markersize=8,label='EE-IoT-WSN-GGNN(Proposed)')

plt.xlabel("Nodes",fontsize=12,fontweight='bold')
plt.ylabel("Network Scalability (%)",fontsize=12,fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True,alpha=0.4)

plt.tight_layout()
plt.savefig("network_scalability.png",dpi=600)
plt.savefig("network_scalability.jpeg",dpi=600)
plt.savefig("network_scalability.tiff",dpi=600)
plt.close()

# -------- Figure 3 : Congestion Level --------
mee = [15.1,15.7,15.8,15.9,16.0,16.2]
mpdp = [17.1,17.7,17.9,18.3,18.5,19.1]
lmnn = [18.8,19.5,19.8,20.1,20.8,21.1]
ggnn = [13.0,13.5,13.6,13.7,13.8,14.0]

plt.figure(figsize=(7,4.5))

plt.plot(time, mee, marker='D', linewidth=3, markersize=8,label='MEE-WSN-DT')
plt.plot(time, mpdp, marker='v', linewidth=3, markersize=8,label='EE-MPDP-WSN')
plt.plot(time, lmnn, marker='s', linewidth=3, markersize=8,label='LMNN-EE-WSN')
plt.plot(time, ggnn, marker='o', linewidth=3.5, markersize=8,label='EE-IoT-WSN-GGNN(Proposed)')

plt.xlabel("Time(sec)",fontsize=12,fontweight='bold')
plt.ylabel("Congestion Level (%)",fontsize=12,fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True,alpha=0.4)

plt.tight_layout()
plt.savefig("congestion_level.png",dpi=600)
plt.savefig("congestion_level.jpeg",dpi=600)
plt.savefig("congestion_level.tiff",dpi=600)
plt.close()

# -------- Figure 4 : Quality of Service --------
mee = [87.8,89.2,90.9,91.9,92.9,95.5]
mpdp = [83.2,84.5,85.2,86.0,86.5,87.8]
lmnn = [78.0,79.5,80.0,80.6,81.2,82.0]
ggnn = [94.5,97.2,98.4,99.2,99.4,99.5]

plt.figure(figsize=(7,4.5))

plt.plot(nodes, mee, marker='D', linewidth=3, markersize=8,label='MEE-WSN-DT')
plt.plot(nodes, mpdp, marker='v', linewidth=3, markersize=8,label='EE-MPDP-WSN')
plt.plot(nodes, lmnn, marker='s', linewidth=3, markersize=8,label='LMNN-EE-WSN')
plt.plot(nodes, ggnn, marker='o', linewidth=3.5, markersize=8,label='EE-IoT-WSN-GGNN(Proposed)')

plt.xlabel("Nodes",fontsize=12,fontweight='bold')
plt.ylabel("Quality of service (%)",fontsize=12,fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True,alpha=0.4)

plt.tight_layout()
plt.savefig("quality_of_service.png",dpi=600)
plt.savefig("quality_of_service.jpeg",dpi=600)
plt.savefig("quality_of_service.tiff",dpi=600)
plt.close()

print("All figures saved successfully.")
# Out:
# All figures saved successfully.
